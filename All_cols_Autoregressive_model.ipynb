# %% [markdown]
# ### PREDICT THE REST OF THE COLUMNS
# #### Since we've already predicted mean_temperature
# ####  Use Autooregressive model since it's less resource intensive compared to Arima

# %%
import pandas as pd

import seaborn as sns

from statsmodels.graphics.tsaplots import plot_pacf

from helper_functions import *

import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
# Read csv files
train_df = pd.read_csv("DailyDelhiClimateTrain.csv", parse_dates=True,index_col='date')
test_df = pd.read_csv("DailyDelhiClimateTest.csv", parse_dates=True,index_col='date')

# %%
# plot pacs for the rest of the colummns
for col in train_df.columns[1:]:
    pacf_plot(train_df, col)
sns.set(style="darkgrid")

# %% [markdown]
# From the above plots
#
# Humidity has a lag 16 with statistical significance,
#
# Wind Speed has a lag 20 with statistical significance,
#
# Mean Pressure has a lag 1 with statistical significance,

# %%
for col in train_df.columns[1:]:
    autoregressive_model(train_df=train_df, test_df=test_df, col=col, lag=None)
# Out:
# humidity Mean Absolute Error of Baseline Model: 13.4304
# humidity Has beaten the baseline model with a test MAE of 5.6746
# wind_speed Mean Absolute Error of Baseline Model: 3.4591
# wind_speed Has beaten the baseline model with a test MAE of 2.6192
# meanpressure Mean Absolute Error of Baseline Model: 13.9666
# meanpressure Has beaten the baseline model with a test MAE of 13.4724
